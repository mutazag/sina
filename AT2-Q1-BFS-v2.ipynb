# %%
import networkx as nx
import matplotlib.pyplot as plt
from helpers import samples, graph_search

sample = samples.graph1()
gs = graph_search.GraphSearch(sample)

# %%
gs.simulate_bfs('A')
# Out:
# processing node A
# 	iteration: 0
# processing node B
# 	iteration: 1
# processing node E
# 	iteration: 2
# processing node F
# 	iteration: 3
# processing node D
# 	iteration: 4
# processing node H
# 	iteration: 5
# processing node G
# 	iteration: 6
# processing node J
# 	iteration: 7
# processing node I
# 	iteration: 8
# processing node C
# 	iteration: 9

# %%
gs.simulate_bfs('G')
# Out:
# processing node G
# 	iteration: 0
# processing node C
# 	iteration: 1
# processing node F
# 	iteration: 2
# processing node J
# 	iteration: 3
# processing node B
# 	iteration: 4
# processing node I
# 	iteration: 5
# processing node A
# 	iteration: 6
# processing node H
# 	iteration: 7
# processing node E
# 	iteration: 8
# processing node D
# 	iteration: 9

# %%
gs.simulate_bfs('F')
# Out:
# processing node F
# 	iteration: 0
# processing node B
# 	iteration: 1
# processing node G
# 	iteration: 2
# processing node J
# 	iteration: 3
# processing node I
# 	iteration: 4
# processing node A
# 	iteration: 5
# processing node C
# 	iteration: 6
# processing node H
# 	iteration: 7
# processing node E
# 	iteration: 8
# processing node D
# 	iteration: 9

# %% [markdown]
# # another graph

# %%
gs2 = graph_search.GraphSearch(samples.SampleGraph())

# %%
gs2.simulate_bfs('A')
# Out:
# processing node A
# 	iteration: 0
# processing node B
# 	iteration: 1
# processing node C
# 	iteration: 2

# %%
gs2.simulate_bfs('C')
# Out:
# processing node C
# 	iteration: 0
# processing node A
# 	iteration: 1
# processing node B
# 	iteration: 2
